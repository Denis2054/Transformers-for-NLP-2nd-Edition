# %% [markdown]
# #Sentiment Analysis with AllenNLP, Hugging Face and GPT-3
#
# Copyright 2022, Denis Rothman
#
# Resources
#
# [AllenNLP](https://demo.allennlp.org/sentiment-analysis)
#
# [Hugging Face Pipelines](https://huggingface.co/transformers/main_classes/pipelines.html)
#
# [Hugging Face Models](https://huggingface.co/models)
#
# [OpenAI GPT-3](https://beta.openai.com/examples/default-adv-tweet-classifier)

# %% [markdown]
# #Sentiment Analysis with AllenNLP

# %%
# !pip install allennlp==1.0.0 allennlp-models==1.0.0
# Out:
# Collecting allennlp==1.0.0
#   Downloading allennlp-1.0.0-py3-none-any.whl (473 kB)
#      |████████████████████████████████| 473 kB 5.0 MB/s
# Collecting allennlp-models==1.0.0
#   Downloading allennlp_models-1.0.0-py3-none-any.whl (282 kB)
#      |████████████████████████████████| 282 kB 48.6 MB/s
# Requirement already satisfied: nltk in /usr/local/lib/python3.7/dist-packages (from allennlp==1.0.0) (3.2.5)
# Requirement already satisfied: pytest in /usr/local/lib/python3.7/dist-packages (from allennlp==1.0.0) (3.6.4)
# Collecting filelock<3.1,>=3.0
#   Downloading filelock-3.0.12-py3-none-any.whl (7.6 kB)
# Requirement already satisfied: tqdm>=4.19 in /usr/local/lib/python3.7/dist-packages (from allennlp==1.0.0) (4.62.3)
# Collecting boto3
#   Downloading boto3-1.20.37-py3-none-any.whl (131 kB)
#      |████████████████████████████████| 131 kB 45.4 MB/s
# Collecting tensorboardX>=1.2
#   Downloading tensorboardX-2.4.1-py2.py3-none-any.whl (124 kB)
#      |████████████████████████████████| 124 kB 53.7 MB/s
# Requirement already satisfied: scikit-learn in /usr/local/lib/python3.7/dist-packages (from allennlp==1.0.0) (1.0.2)
# Collecting torch<1.6.0,>=1.5.0
#   Downloading torch-1.5.1-cp37-cp37m-manylinux1_x86_64.whl (753.2 MB)
#      |████████████████████████████████| 753.2 MB 14 kB/s
# Requirement already satisfied: spacy<2.3,>=2.1.0 in /usr/local/lib/python3.7/dist-packages (from allennlp==1.0.0) (2.2.4)
# Requirement already satisfied: requests>=2.18 in /usr/local/lib/python3.7/dist-packages (from allennlp==1.0.0) (2.23.0)
# Requirement already satisfied: numpy in /usr/local/lib/python3.7/dist-packages (from allennlp==1.0.0) (1.19.5)
# Collecting jsonpickle
#   Downloading jsonpickle-2.1.0-py2.py3-none-any.whl (38 kB)
# Collecting jsonnet>=0.10.0
#   Downloading jsonnet-0.18.0.tar.gz (592 kB)
#      |████████████████████████████████| 592 kB 71.7 MB/s
# Requirement already satisfied: scipy in /usr/local/lib/python3.7/dist-packages (from allennlp==1.0.0) (1.4.1)
# Collecting transformers<2.12,>=2.9
#   Downloading transformers-2.11.0-py3-none-any.whl (674 kB)
#      |████████████████████████████████| 674 kB 56.3 MB/s
# Collecting overrides==3.0.0
#   Downloading overrides-3.0.0.tar.gz (4.5 kB)
# Requirement already satisfied: h5py in /usr/local/lib/python3.7/dist-packages (from allennlp==1.0.0) (3.1.0)
# Collecting py-rouge==1.1
#   Downloading py_rouge-1.1-py3-none-any.whl (56 kB)
#      |████████████████████████████████| 56 kB 4.9 MB/s
# Collecting conllu==3.0
#   Downloading conllu-3.0-py2.py3-none-any.whl (14 kB)
# Collecting word2number>=1.1
#   Downloading word2number-1.1.zip (9.7 kB)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.7/dist-packages (from requests>=2.18->allennlp==1.0.0) (3.0.4)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.7/dist-packages (from requests>=2.18->allennlp==1.0.0) (1.24.3)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.7/dist-packages (from requests>=2.18->allennlp==1.0.0) (2021.10.8)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.7/dist-packages (from requests>=2.18->allennlp==1.0.0) (2.10)
# Requirement already satisfied: preshed<3.1.0,>=3.0.2 in /usr/local/lib/python3.7/dist-packages (from spacy<2.3,>=2.1.0->allennlp==1.0.0) (3.0.6)
# Requirement already satisfied: murmurhash<1.1.0,>=0.28.0 in /usr/local/lib/python3.7/dist-packages (from spacy<2.3,>=2.1.0->allennlp==1.0.0) (1.0.6)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.7/dist-packages (from spacy<2.3,>=2.1.0->allennlp==1.0.0) (57.4.0)
# Requirement already satisfied: blis<0.5.0,>=0.4.0 in /usr/local/lib/python3.7/dist-packages (from spacy<2.3,>=2.1.0->allennlp==1.0.0) (0.4.1)
# Requirement already satisfied: wasabi<1.1.0,>=0.4.0 in /usr/local/lib/python3.7/dist-packages (from spacy<2.3,>=2.1.0->allennlp==1.0.0) (0.9.0)
# Requirement already satisfied: cymem<2.1.0,>=2.0.2 in /usr/local/lib/python3.7/dist-packages (from spacy<2.3,>=2.1.0->allennlp==1.0.0) (2.0.6)
# Requirement already satisfied: srsly<1.1.0,>=1.0.2 in /usr/local/lib/python3.7/dist-packages (from spacy<2.3,>=2.1.0->allennlp==1.0.0) (1.0.5)
# Requirement already satisfied: thinc==7.4.0 in /usr/local/lib/python3.7/dist-packages (from spacy<2.3,>=2.1.0->allennlp==1.0.0) (7.4.0)
# Requirement already satisfied: catalogue<1.1.0,>=0.0.7 in /usr/local/lib/python3.7/dist-packages (from spacy<2.3,>=2.1.0->allennlp==1.0.0) (1.0.0)
# Requirement already satisfied: plac<1.2.0,>=0.9.6 in /usr/local/lib/python3.7/dist-packages (from spacy<2.3,>=2.1.0->allennlp==1.0.0) (1.1.3)
# Requirement already satisfied: importlib-metadata>=0.20 in /usr/local/lib/python3.7/dist-packages (from catalogue<1.1.0,>=0.0.7->spacy<2.3,>=2.1.0->allennlp==1.0.0) (4.10.0)
# Requirement already satisfied: zipp>=0.5 in /usr/local/lib/python3.7/dist-packages (from importlib-metadata>=0.20->catalogue<1.1.0,>=0.0.7->spacy<2.3,>=2.1.0->allennlp==1.0.0) (3.7.0)
# Requirement already satisfied: typing-extensions>=3.6.4 in /usr/local/lib/python3.7/dist-packages (from importlib-metadata>=0.20->catalogue<1.1.0,>=0.0.7->spacy<2.3,>=2.1.0->allennlp==1.0.0) (3.10.0.2)
# Requirement already satisfied: protobuf>=3.8.0 in /usr/local/lib/python3.7/dist-packages (from tensorboardX>=1.2->allennlp==1.0.0) (3.17.3)
# Requirement already satisfied: six>=1.9 in /usr/local/lib/python3.7/dist-packages (from protobuf>=3.8.0->tensorboardX>=1.2->allennlp==1.0.0) (1.15.0)
# Requirement already satisfied: future in /usr/local/lib/python3.7/dist-packages (from torch<1.6.0,>=1.5.0->allennlp==1.0.0) (0.16.0)
# Requirement already satisfied: packaging in /usr/local/lib/python3.7/dist-packages (from transformers<2.12,>=2.9->allennlp==1.0.0) (21.3)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.7/dist-packages (from transformers<2.12,>=2.9->allennlp==1.0.0) (2019.12.20)
# Collecting sacremoses
#   Downloading sacremoses-0.0.47-py2.py3-none-any.whl (895 kB)
#      |████████████████████████████████| 895 kB 56.4 MB/s
# Collecting sentencepiece
#   Downloading sentencepiece-0.1.96-cp37-cp37m-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (1.2 MB)
#      |████████████████████████████████| 1.2 MB 58.6 MB/s
# Collecting tokenizers==0.7.0
#   Downloading tokenizers-0.7.0-cp37-cp37m-manylinux1_x86_64.whl (5.6 MB)
#      |████████████████████████████████| 5.6 MB 50.1 MB/s
# Collecting botocore<1.24.0,>=1.23.37
#   Downloading botocore-1.23.37-py3-none-any.whl (8.5 MB)
#      |████████████████████████████████| 8.5 MB 39.2 MB/s
# Collecting jmespath<1.0.0,>=0.7.1
#   Downloading jmespath-0.10.0-py2.py3-none-any.whl (24 kB)
# Collecting s3transfer<0.6.0,>=0.5.0
#   Downloading s3transfer-0.5.0-py3-none-any.whl (79 kB)
#      |████████████████████████████████| 79 kB 7.4 MB/s
# Collecting urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1
#   Downloading urllib3-1.25.11-py2.py3-none-any.whl (127 kB)
#      |████████████████████████████████| 127 kB 61.9 MB/s
# Requirement already satisfied: python-dateutil<3.0.0,>=2.1 in /usr/local/lib/python3.7/dist-packages (from botocore<1.24.0,>=1.23.37->boto3->allennlp==1.0.0) (2.8.2)
# Requirement already satisfied: cached-property in /usr/local/lib/python3.7/dist-packages (from h5py->allennlp==1.0.0) (1.5.2)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in /usr/local/lib/python3.7/dist-packages (from packaging->transformers<2.12,>=2.9->allennlp==1.0.0) (3.0.6)
# Requirement already satisfied: atomicwrites>=1.0 in /usr/local/lib/python3.7/dist-packages (from pytest->allennlp==1.0.0) (1.4.0)
# Requirement already satisfied: attrs>=17.4.0 in /usr/local/lib/python3.7/dist-packages (from pytest->allennlp==1.0.0) (21.4.0)
# Requirement already satisfied: pluggy<0.8,>=0.5 in /usr/local/lib/python3.7/dist-packages (from pytest->allennlp==1.0.0) (0.7.1)
# Requirement already satisfied: more-itertools>=4.0.0 in /usr/local/lib/python3.7/dist-packages (from pytest->allennlp==1.0.0) (8.12.0)
# Requirement already satisfied: py>=1.5.0 in /usr/local/lib/python3.7/dist-packages (from pytest->allennlp==1.0.0) (1.11.0)
# Requirement already satisfied: click in /usr/local/lib/python3.7/dist-packages (from sacremoses->transformers<2.12,>=2.9->allennlp==1.0.0) (7.1.2)
# Requirement already satisfied: joblib in /usr/local/lib/python3.7/dist-packages (from sacremoses->transformers<2.12,>=2.9->allennlp==1.0.0) (1.1.0)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /usr/local/lib/python3.7/dist-packages (from scikit-learn->allennlp==1.0.0) (3.0.0)
# Building wheels for collected packages: overrides, jsonnet, word2number
#   Building wheel for overrides (setup.py) ... done
#   Created wheel for overrides: filename=overrides-3.0.0-py3-none-any.whl size=5674 sha256=63613b643244779050a3f384a3345f0b0f3661a23429588e08266457df8dd29c
#   Stored in directory: /root/.cache/pip/wheels/7d/c6/bf/bff44a9cc6c899e2d77ec968b2d0707616a3d66e4ebefb2411
#   Building wheel for jsonnet (setup.py) ... done
#   Created wheel for jsonnet: filename=jsonnet-0.18.0-cp37-cp37m-linux_x86_64.whl size=3994562 sha256=b55f8952b5976a452fb43d4610b79accfea4f2b56203327df6037e3ccfe20e1b
#   Stored in directory: /root/.cache/pip/wheels/a9/63/f9/a653f9c21575e6ff271ee6a49939aa002005174cea6c35919d
#   Building wheel for word2number (setup.py) ... done
#   Created wheel for word2number: filename=word2number-1.1-py3-none-any.whl size=5582 sha256=86e7080dd67dbc418b7fbffc1f37b3d2153334a22c1283f3702f57fe6ad40ed9
#   Stored in directory: /root/.cache/pip/wheels/4b/c3/77/a5f48aeb0d3efb7cd5ad61cbd3da30bbf9ffc9662b07c9f879
# Successfully built overrides jsonnet word2number
# Installing collected packages: urllib3, jmespath, botocore, tokenizers, sentencepiece, sacremoses, s3transfer, filelock, transformers, torch, tensorboardX, overrides, jsonpickle, jsonnet, boto3, word2number, py-rouge, conllu, allennlp, allennlp-models
#   Attempting uninstall: urllib3
#     Found existing installation: urllib3 1.24.3
#     Uninstalling urllib3-1.24.3:
#       Successfully uninstalled urllib3-1.24.3
#   Attempting uninstall: filelock
#     Found existing installation: filelock 3.4.2
#     Uninstalling filelock-3.4.2:
#       Successfully uninstalled filelock-3.4.2
#   Attempting uninstall: torch
#     Found existing installation: torch 1.10.0+cu111
#     Uninstalling torch-1.10.0+cu111:
#       Successfully uninstalled torch-1.10.0+cu111
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# torchvision 0.11.1+cu111 requires torch==1.10.0, but you have torch 1.5.1 which is incompatible.
# torchtext 0.11.0 requires torch==1.10.0, but you have torch 1.5.1 which is incompatible.
# torchaudio 0.10.0+cu111 requires torch==1.10.0, but you have torch 1.5.1 which is incompatible.
# datascience 0.10.6 requires folium==0.2.1, but you have folium 0.8.3 which is incompatible.
# Successfully installed allennlp-1.0.0 allennlp-models-1.0.0 boto3-1.20.37 botocore-1.23.37 conllu-3.0 filelock-3.0.12 jmespath-0.10.0 jsonnet-0.18.0 jsonpickle-2.1.0 overrides-3.0.0 py-rouge-1.1 s3transfer-0.5.0 sacremoses-0.0.47 sentencepiece-0.1.96 tensorboardX-2.4.1 tokenizers-0.7.0 torch-1.5.1 transformers-2.11.0 urllib3-1.25.11 word2number-1.1

# %% [markdown]
# Bash

# %%
# !echo '{"sentence": "Whether or not you're enlightened by any of Derrida's lectures on the other and the self, Derrida is an undeniably fascinating and playful fellow."}' | \
allennlp predict https://storage.googleapis.com/allennlp-public-models/sst-roberta-large-2020.06.08.tar.gz -
# Out:
# 2022-01-16 12:03:37,385 - INFO - transformers.file_utils - PyTorch version 1.5.1 available.
# 2022-01-16 12:03:42,314 - INFO - transformers.file_utils - TensorFlow version 2.7.0 available.
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt.zip.
# [nltk_data] Downloading package wordnet to /root/nltk_data...
# [nltk_data]   Unzipping corpora/wordnet.zip.
# 2022-01-16 12:03:45,007 - INFO - allennlp.common.file_utils - checking cache for https://storage.googleapis.com/allennlp-public-models/sst-roberta-large-2020.06.08.tar.gz at /root/.allennlp/cache/8255466347f7b3a13b6bf71883dca4a02eefc30ce15004b8b41ba231b0e3de6d.f4aa9e5021ce7bf3c17488c8924b4aad654883a2f0b65528127695344bb741ac
# 2022-01-16 12:03:45,007 - INFO - allennlp.common.file_utils - waiting to acquire lock on /root/.allennlp/cache/8255466347f7b3a13b6bf71883dca4a02eefc30ce15004b8b41ba231b0e3de6d.f4aa9e5021ce7bf3c17488c8924b4aad654883a2f0b65528127695344bb741ac
# 2022-01-16 12:03:45,008 - INFO - filelock - Lock 140329937642704 acquired on /root/.allennlp/cache/8255466347f7b3a13b6bf71883dca4a02eefc30ce15004b8b41ba231b0e3de6d.f4aa9e5021ce7bf3c17488c8924b4aad654883a2f0b65528127695344bb741ac.lock
# 2022-01-16 12:03:45,008 - INFO - allennlp.common.file_utils - https://storage.googleapis.com/allennlp-public-models/sst-roberta-large-2020.06.08.tar.gz not found in cache, downloading to /root/.allennlp/cache/tmpdouaj8er.tmp
# 100% 1286605089/1286605089 [00:26<00:00, 49169485.34B/s]
# 2022-01-16 12:04:11,324 - INFO - allennlp.common.file_utils - Renaming temp file /root/.allennlp/cache/tmpdouaj8er.tmp to cache at /root/.allennlp/cache/8255466347f7b3a13b6bf71883dca4a02eefc30ce15004b8b41ba231b0e3de6d.f4aa9e5021ce7bf3c17488c8924b4aad654883a2f0b65528127695344bb741ac
# 2022-01-16 12:04:11,324 - INFO - allennlp.common.file_utils - creating metadata file for /root/.allennlp/cache/8255466347f7b3a13b6bf71883dca4a02eefc30ce15004b8b41ba231b0e3de6d.f4aa9e5021ce7bf3c17488c8924b4aad654883a2f0b65528127695344bb741ac
# 2022-01-16 12:04:11,325 - INFO - filelock - Lock 140329937642704 released on /root/.allennlp/cache/8255466347f7b3a13b6bf71883dca4a02eefc30ce15004b8b41ba231b0e3de6d.f4aa9e5021ce7bf3c17488c8924b4aad654883a2f0b65528127695344bb741ac.lock
# 2022-01-16 12:04:11,325 - INFO - allennlp.models.archival - loading archive file https://storage.googleapis.com/allennlp-public-models/sst-roberta-large-2020.06.08.tar.gz from cache at /root/.allennlp/cache/8255466347f7b3a13b6bf71883dca4a02eefc30ce15004b8b41ba231b0e3de6d.f4aa9e5021ce7bf3c17488c8924b4aad654883a2f0b65528127695344bb741ac
# 2022-01-16 12:04:11,325 - INFO - allennlp.models.archival - extracting archive file /root/.allennlp/cache/8255466347f7b3a13b6bf71883dca4a02eefc30ce15004b8b41ba231b0e3de6d.f4aa9e5021ce7bf3c17488c8924b4aad654883a2f0b65528127695344bb741ac to temp dir /tmp/tmpfc_r79ne
# 2022-01-16 12:04:26,477 - INFO - allennlp.common.params - type = from_instances
# 2022-01-16 12:04:26,478 - INFO - allennlp.data.vocabulary - Loading token dictionary from /tmp/tmpfc_r79ne/vocabulary.
# 2022-01-16 12:04:26,478 - INFO - filelock - Lock 140329924464400 acquired on /tmp/tmpfc_r79ne/vocabulary/.lock
# 2022-01-16 12:04:26,478 - INFO - filelock - Lock 140329924464400 released on /tmp/tmpfc_r79ne/vocabulary/.lock
# 2022-01-16 12:04:26,478 - INFO - allennlp.common.params - model.type = basic_classifier
# 2022-01-16 12:04:26,479 - INFO - allennlp.common.params - model.regularizer = None
# 2022-01-16 12:04:26,479 - INFO - allennlp.common.params - model.text_field_embedder.type = basic
# 2022-01-16 12:04:26,479 - INFO - allennlp.common.params - model.text_field_embedder.token_embedders.tokens.type = pretrained_transformer_mismatched
# 2022-01-16 12:04:26,480 - INFO - allennlp.common.params - model.text_field_embedder.token_embedders.tokens.model_name = roberta-large
# 2022-01-16 12:04:26,480 - INFO - allennlp.common.params - model.text_field_embedder.token_embedders.tokens.max_length = None
# 2022-01-16 12:04:26,480 - INFO - allennlp.common.params - model.text_field_embedder.token_embedders.tokens.train_parameters = True
# 2022-01-16 12:04:26,648 - INFO - filelock - Lock 140329922336464 acquired on /root/.cache/torch/transformers/c22e0b5bbb7c0cb93a87a2ae01263ae715b4c18d692b1740ce72cacaa99ad184.2d28da311092e99a05f9ee17520204614d60b0bfdb32f8a75644df7737b6a748.lock
# 2022-01-16 12:04:26,648 - INFO - transformers.file_utils - https://s3.amazonaws.com/models.huggingface.co/bert/roberta-large-config.json not found in cache or force_download set to True, downloading to /root/.cache/torch/transformers/tmpu5njhkvl
# Downloading: 100% 482/482 [00:00<00:00, 349kB/s]
# 2022-01-16 12:04:26,812 - INFO - transformers.file_utils - storing https://s3.amazonaws.com/models.huggingface.co/bert/roberta-large-config.json in cache at /root/.cache/torch/transformers/c22e0b5bbb7c0cb93a87a2ae01263ae715b4c18d692b1740ce72cacaa99ad184.2d28da311092e99a05f9ee17520204614d60b0bfdb32f8a75644df7737b6a748
# 2022-01-16 12:04:26,812 - INFO - transformers.file_utils - creating metadata file for /root/.cache/torch/transformers/c22e0b5bbb7c0cb93a87a2ae01263ae715b4c18d692b1740ce72cacaa99ad184.2d28da311092e99a05f9ee17520204614d60b0bfdb32f8a75644df7737b6a748
# 2022-01-16 12:04:26,813 - INFO - filelock - Lock 140329922336464 released on /root/.cache/torch/transformers/c22e0b5bbb7c0cb93a87a2ae01263ae715b4c18d692b1740ce72cacaa99ad184.2d28da311092e99a05f9ee17520204614d60b0bfdb32f8a75644df7737b6a748.lock
# 2022-01-16 12:04:26,813 - INFO - transformers.configuration_utils - loading configuration file https://s3.amazonaws.com/models.huggingface.co/bert/roberta-large-config.json from cache at /root/.cache/torch/transformers/c22e0b5bbb7c0cb93a87a2ae01263ae715b4c18d692b1740ce72cacaa99ad184.2d28da311092e99a05f9ee17520204614d60b0bfdb32f8a75644df7737b6a748
# 2022-01-16 12:04:26,813 - INFO - transformers.configuration_utils - Model config RobertaConfig {
#   "architectures": [
#     "RobertaForMaskedLM"
#   ],
#   "attention_probs_dropout_prob": 0.1,
#   "bos_token_id": 0,
#   "eos_token_id": 2,
#   "hidden_act": "gelu",
#   "hidden_dropout_prob": 0.1,
#   "hidden_size": 1024,
#   "initializer_range": 0.02,
#   "intermediate_size": 4096,
#   "layer_norm_eps": 1e-05,
#   "max_position_embeddings": 514,
#   "model_type": "roberta",
#   "num_attention_heads": 16,
#   "num_hidden_layers": 24,
#   "pad_token_id": 1,
#   "type_vocab_size": 1,
#   "vocab_size": 50265
# }
#
# 2022-01-16 12:04:27,002 - INFO - filelock - Lock 140333860800272 acquired on /root/.cache/torch/transformers/2339ac1858323405dffff5156947669fed6f63a0c34cfab35bda4f78791893d2.fc7abf72755ecc4a75d0d336a93c1c63358d2334f5998ed326f3b0da380bf536.lock
# 2022-01-16 12:04:27,002 - INFO - transformers.file_utils - https://cdn.huggingface.co/roberta-large-pytorch_model.bin not found in cache or force_download set to True, downloading to /root/.cache/torch/transformers/tmpart_kpts
# Downloading: 100% 1.43G/1.43G [00:38<00:00, 37.1MB/s]
# 2022-01-16 12:05:05,678 - INFO - transformers.file_utils - storing https://cdn.huggingface.co/roberta-large-pytorch_model.bin in cache at /root/.cache/torch/transformers/2339ac1858323405dffff5156947669fed6f63a0c34cfab35bda4f78791893d2.fc7abf72755ecc4a75d0d336a93c1c63358d2334f5998ed326f3b0da380bf536
# 2022-01-16 12:05:05,679 - INFO - transformers.file_utils - creating metadata file for /root/.cache/torch/transformers/2339ac1858323405dffff5156947669fed6f63a0c34cfab35bda4f78791893d2.fc7abf72755ecc4a75d0d336a93c1c63358d2334f5998ed326f3b0da380bf536
# 2022-01-16 12:05:05,679 - INFO - filelock - Lock 140333860800272 released on /root/.cache/torch/transformers/2339ac1858323405dffff5156947669fed6f63a0c34cfab35bda4f78791893d2.fc7abf72755ecc4a75d0d336a93c1c63358d2334f5998ed326f3b0da380bf536.lock
# 2022-01-16 12:05:05,679 - INFO - transformers.modeling_utils - loading weights file https://cdn.huggingface.co/roberta-large-pytorch_model.bin from cache at /root/.cache/torch/transformers/2339ac1858323405dffff5156947669fed6f63a0c34cfab35bda4f78791893d2.fc7abf72755ecc4a75d0d336a93c1c63358d2334f5998ed326f3b0da380bf536
# 2022-01-16 12:05:19,384 - INFO - transformers.configuration_utils - loading configuration file https://s3.amazonaws.com/models.huggingface.co/bert/roberta-large-config.json from cache at /root/.cache/torch/transformers/c22e0b5bbb7c0cb93a87a2ae01263ae715b4c18d692b1740ce72cacaa99ad184.2d28da311092e99a05f9ee17520204614d60b0bfdb32f8a75644df7737b6a748
# 2022-01-16 12:05:19,385 - INFO - transformers.configuration_utils - Model config RobertaConfig {
#   "architectures": [
#     "RobertaForMaskedLM"
#   ],
#   "attention_probs_dropout_prob": 0.1,
#   "bos_token_id": 0,
#   "eos_token_id": 2,
#   "hidden_act": "gelu",
#   "hidden_dropout_prob": 0.1,
#   "hidden_size": 1024,
#   "initializer_range": 0.02,
#   "intermediate_size": 4096,
#   "layer_norm_eps": 1e-05,
#   "max_position_embeddings": 514,
#   "model_type": "roberta",
#   "num_attention_heads": 16,
#   "num_hidden_layers": 24,
#   "pad_token_id": 1,
#   "type_vocab_size": 1,
#   "vocab_size": 50265
# }
#
# 2022-01-16 12:05:19,560 - INFO - filelock - Lock 140329922707152 acquired on /root/.cache/torch/transformers/1ae1f5b6e2b22b25ccc04c000bb79ca847aa226d0761536b011cf7e5868f0655.ef00af9e673c7160b4d41cfda1f48c5f4cba57d5142754525572a846a1ab1b9b.lock
# 2022-01-16 12:05:19,561 - INFO - transformers.file_utils - https://s3.amazonaws.com/models.huggingface.co/bert/roberta-large-vocab.json not found in cache or force_download set to True, downloading to /root/.cache/torch/transformers/tmpl_dq9772
# Downloading: 100% 899k/899k [00:00<00:00, 5.70MB/s]
# 2022-01-16 12:05:19,912 - INFO - transformers.file_utils - storing https://s3.amazonaws.com/models.huggingface.co/bert/roberta-large-vocab.json in cache at /root/.cache/torch/transformers/1ae1f5b6e2b22b25ccc04c000bb79ca847aa226d0761536b011cf7e5868f0655.ef00af9e673c7160b4d41cfda1f48c5f4cba57d5142754525572a846a1ab1b9b
# 2022-01-16 12:05:19,912 - INFO - transformers.file_utils - creating metadata file for /root/.cache/torch/transformers/1ae1f5b6e2b22b25ccc04c000bb79ca847aa226d0761536b011cf7e5868f0655.ef00af9e673c7160b4d41cfda1f48c5f4cba57d5142754525572a846a1ab1b9b
# 2022-01-16 12:05:19,913 - INFO - filelock - Lock 140329922707152 released on /root/.cache/torch/transformers/1ae1f5b6e2b22b25ccc04c000bb79ca847aa226d0761536b011cf7e5868f0655.ef00af9e673c7160b4d41cfda1f48c5f4cba57d5142754525572a846a1ab1b9b.lock
# 2022-01-16 12:05:20,095 - INFO - filelock - Lock 140329906907408 acquired on /root/.cache/torch/transformers/f8f83199a6270d582d6245dc100e99c4155de81c9745c6248077018fe01abcfb.70bec105b4158ed9a1747fea67a43f5dee97855c64d62b6ec3742f4cfdb5feda.lock
# 2022-01-16 12:05:20,095 - INFO - transformers.file_utils - https://s3.amazonaws.com/models.huggingface.co/bert/roberta-large-merges.txt not found in cache or force_download set to True, downloading to /root/.cache/torch/transformers/tmp16503nns
# Downloading: 100% 456k/456k [00:00<00:00, 3.07MB/s]
# 2022-01-16 12:05:20,494 - INFO - transformers.file_utils - storing https://s3.amazonaws.com/models.huggingface.co/bert/roberta-large-merges.txt in cache at /root/.cache/torch/transformers/f8f83199a6270d582d6245dc100e99c4155de81c9745c6248077018fe01abcfb.70bec105b4158ed9a1747fea67a43f5dee97855c64d62b6ec3742f4cfdb5feda
# 2022-01-16 12:05:20,494 - INFO - transformers.file_utils - creating metadata file for /root/.cache/torch/transformers/f8f83199a6270d582d6245dc100e99c4155de81c9745c6248077018fe01abcfb.70bec105b4158ed9a1747fea67a43f5dee97855c64d62b6ec3742f4cfdb5feda
# 2022-01-16 12:05:20,494 - INFO - filelock - Lock 140329906907408 released on /root/.cache/torch/transformers/f8f83199a6270d582d6245dc100e99c4155de81c9745c6248077018fe01abcfb.70bec105b4158ed9a1747fea67a43f5dee97855c64d62b6ec3742f4cfdb5feda.lock
# 2022-01-16 12:05:20,495 - INFO - transformers.tokenization_utils - loading file https://s3.amazonaws.com/models.huggingface.co/bert/roberta-large-vocab.json from cache at /root/.cache/torch/transformers/1ae1f5b6e2b22b25ccc04c000bb79ca847aa226d0761536b011cf7e5868f0655.ef00af9e673c7160b4d41cfda1f48c5f4cba57d5142754525572a846a1ab1b9b
# 2022-01-16 12:05:20,495 - INFO - transformers.tokenization_utils - loading file https://s3.amazonaws.com/models.huggingface.co/bert/roberta-large-merges.txt from cache at /root/.cache/torch/transformers/f8f83199a6270d582d6245dc100e99c4155de81c9745c6248077018fe01abcfb.70bec105b4158ed9a1747fea67a43f5dee97855c64d62b6ec3742f4cfdb5feda
# 2022-01-16 12:05:20,760 - INFO - transformers.configuration_utils - loading configuration file https://s3.amazonaws.com/models.huggingface.co/bert/roberta-large-config.json from cache at /root/.cache/torch/transformers/c22e0b5bbb7c0cb93a87a2ae01263ae715b4c18d692b1740ce72cacaa99ad184.2d28da311092e99a05f9ee17520204614d60b0bfdb32f8a75644df7737b6a748
# 2022-01-16 12:05:20,761 - INFO - transformers.configuration_utils - Model config RobertaConfig {
#   "architectures": [
#     "RobertaForMaskedLM"
#   ],
#   "attention_probs_dropout_prob": 0.1,
#   "bos_token_id": 0,
#   "eos_token_id": 2,
#   "hidden_act": "gelu",
#   "hidden_dropout_prob": 0.1,
#   "hidden_size": 1024,
#   "initializer_range": 0.02,
#   "intermediate_size": 4096,
#   "layer_norm_eps": 1e-05,
#   "max_position_embeddings": 514,
#   "model_type": "roberta",
#   "num_attention_heads": 16,
#   "num_hidden_layers": 24,
#   "pad_token_id": 1,
#   "type_vocab_size": 1,
#   "vocab_size": 50265
# }
#
# 2022-01-16 12:05:21,061 - INFO - transformers.tokenization_utils - loading file https://s3.amazonaws.com/models.huggingface.co/bert/roberta-large-vocab.json from cache at /root/.cache/torch/transformers/1ae1f5b6e2b22b25ccc04c000bb79ca847aa226d0761536b011cf7e5868f0655.ef00af9e673c7160b4d41cfda1f48c5f4cba57d5142754525572a846a1ab1b9b
# 2022-01-16 12:05:21,062 - INFO - transformers.tokenization_utils - loading file https://s3.amazonaws.com/models.huggingface.co/bert/roberta-large-merges.txt from cache at /root/.cache/torch/transformers/f8f83199a6270d582d6245dc100e99c4155de81c9745c6248077018fe01abcfb.70bec105b4158ed9a1747fea67a43f5dee97855c64d62b6ec3742f4cfdb5feda
# 2022-01-16 12:05:21,169 - INFO - allennlp.common.params - model.seq2vec_encoder.type = cls_pooler
# 2022-01-16 12:05:21,169 - INFO - allennlp.common.params - model.seq2vec_encoder.embedding_dim = 1024
# 2022-01-16 12:05:21,169 - INFO - allennlp.common.params - model.seq2vec_encoder.cls_is_last_token = False
# 2022-01-16 12:05:21,169 - INFO - allennlp.common.params - model.seq2seq_encoder = None
# 2022-01-16 12:05:21,169 - INFO - allennlp.common.params - model.feedforward = None
# 2022-01-16 12:05:21,170 - INFO - allennlp.common.params - model.dropout = 0.1
# 2022-01-16 12:05:21,170 - INFO - allennlp.common.params - model.num_labels = None
# 2022-01-16 12:05:21,170 - INFO - allennlp.common.params - model.label_namespace = labels
# 2022-01-16 12:05:21,170 - INFO - allennlp.common.params - model.namespace = tags
# 2022-01-16 12:05:21,170 - INFO - allennlp.common.params - model.initializer = <allennlp.nn.initializers.InitializerApplicator object at 0x7fa11b606c90>
# 2022-01-16 12:05:21,171 - INFO - allennlp.nn.initializers - Initializing parameters
# 2022-01-16 12:05:21,173 - INFO - allennlp.nn.initializers - Done initializing parameters; the following parameters are using their default initialization from their code
# 2022-01-16 12:05:21,173 - INFO - allennlp.nn.initializers -    _classification_layer.bias
# 2022-01-16 12:05:21,173 - INFO - allennlp.nn.initializers -    _classification_layer.weight
# 2022-01-16 12:05:21,173 - INFO - allennlp.nn.initializers -    _text_field_embedder.token_embedder_tokens._matched_embedder.transformer_model.embeddings.LayerNorm.bias
# 2022-01-16 12:05:21,173 - INFO - allennlp.nn.initializers -    _text_field_embedder.token_embedder_tokens._matched_embedder.transformer_model.embeddings.LayerNorm.weight
# 2022-01-16 12:05:21,173 - INFO - allennlp.nn.initializers -    _text_field_embedder.token_embedder_tokens._matched_embedder.transformer_model.embeddings.position_embeddings.weight
# 2022-01-16 12:05:21,173 - INFO - allennlp.nn.initializers -    _text_field_embedder.token_embedder_tokens._matched_embedder.transformer_model.embeddings.token_type_embeddings.weight
# 2022-01-16 12:05:21,173 - INFO - allennlp.nn.initializers -    _text_field_embedder.token_embedder_tokens._matched_embedder.transformer_model.embeddings.word_embeddings.weight
# 2022-01-16 12:05:21,173 - INFO - allennlp.nn.initializers -    _text_field_embedder.token_embedder_tokens._matched_embedder.transformer_model.encoder.layer.0.attention.output.LayerNorm.bias
# 2022-01-16 12:05:21,173 - INFO - allennlp.nn.initializers -    _text_field_embedder.token_embedder_tokens._matched_embedder.transformer_model.encoder.layer.0.attention.output.LayerNorm.weight
# 2022-01-16 12:05:21,174 - INFO - allennlp.nn.initializers -    _text_field_embedder.token_embedder_tokens._matched_embedder.transformer_model.encoder.layer.0.attention.output.dense.bias
# 2022-01-16 12:05:21,174 - INFO - allennlp.nn.initializers -    _text_field_embedder.token_embedder_tokens._matched_embedder.transformer_model.encoder.layer.0.attention.output.dense.weight
# 2022-01-16 12:05:21,174 - INFO - allennlp.nn.initializers -    _text_field_embedder.token_embedder_tokens._matched_embedder.transformer_model.encoder.layer.0.attention.self.key.bias
# 2022-01-16 12:05:21,174 - INFO - allennlp.nn.initializers -    _text_field_embedder.token_embedder_tokens._matched_embedder.transformer_model.encoder.layer.0.attention.self.key.weight
# 2022-01-16 12:05:21,174 - INFO - allennlp.nn.initializers -    _text_field_embedder.token_embedder_tokens._matched_embedder.transformer_model.encoder.layer.0.attention.self.query.bias
# 2022-01-16 12:05:21,174 - INFO - allennlp.nn.initializers -    _text_field_embedder.token_embedder_tokens._matched_embedder.transformer_model.encoder.layer.0.attention.self.query.weight
# 2022-01-16 12:05:21,174 - INFO - allennlp.nn.initializers -    _text_field_embedder.token_embedder_tokens._matched_embedder.transformer_model.encoder.layer.0.attention.self.value.bias
# 2022-01-16 12:05:21,174 - INFO - allennlp.nn.initializers -    _text_field_embedder.token_embedder_tokens._matched_embedder.transformer_model.encoder.layer.0.attention.self.value.weight
# 2022-01-16 12:05:21,174 - INFO - allennlp.nn.initializers -    _text_field_embedder.token_embedder_tokens._matched_embedder.transformer_model.encoder.layer.0.intermediate.dense.bias
# 2022-01-16 12:05:21,174 - INFO - allennlp.nn.initializers -    _text_field_embedder.token_embedder_tokens._matched_embedder.transformer_model.encoder.layer.0.intermediate.dense.weight
# 2022-01-16 12:05:21,174 - INFO - allennlp.nn.initializers -    _text_field_embedder.token_embedder_tokens._matched_embedder.transformer_model.encoder.layer.0.output.LayerNorm.bias
# 2022-01-16 12:05:21,174 - INFO - allennlp.nn.initializers -    _text_field_embedder.token_embedder_tokens._matched_embedder.transformer_model.encoder.layer.0.output.LayerNorm.weight
# 2022-01-16 12:05:21,174 - INFO - allennlp.nn.initializers -    _text_field_embedder.token_embedder_tokens._matched_embedder.transformer_model.encoder.layer.0.output.dense.bias
# 2022-01-16 12:05:21,174 - INFO - allennlp.nn.initializers -    _text_field_embedder.token_embedder_tokens._matched_embedder.transformer_model.encoder.layer.0.output.dense.weight
# 2022-01-16 12:05:21,174 - INFO - allennlp.nn.initializers -    _text_field_embedder.token_embedder_tokens._matched_embedder.transformer_model.encoder.layer.1.attention.output.LayerNorm.bias
# 2022-01-16 12:05:21,174 - INFO - allennlp.nn.initializers -    _text_field_embedder.token_embedder_tokens._matched_embedder.transformer_model.encoder.layer.1.attention.output.LayerNorm.weight
# 2022-01-16 12:05:21,174 - INFO - allennlp.nn.initializers -    _text_field_embedder.token_embedder_tokens._matched_embedder.transformer_model.encoder.layer.1.attention.output.dense.bias
# 2022-01-16 12:05:21,174 - INFO - allennlp.nn.initializers -    _text_field_embedder.token_embedder_tokens._matched_embedder.transformer_model.encoder.layer.1.attention.output.dense.weight
# 2022-01-16 12:05:21,174 - INFO - allennlp.nn.initializers -    _text_field_embedder.token_embedder_tokens._matched_embedder.transformer_model.encoder.layer.1.attention.self.key.bias
# 2022-01-16 12:05:21,174 - INFO - allennlp.nn.initializers -    _text_field_embedder.token_embedder_tokens._matched_embedder.transformer_model.encoder.layer.1.attention
_field_embedder.token_embedder_tokens._matched_embedder.transformer_model.pooler.dense.weight
# 2022-01-16 12:05:24,483 - INFO - allennlp.common.params - validation_dataset_reader.type = sst_tokens
# 2022-01-16 12:05:24,484 - INFO - allennlp.common.params - validation_dataset_reader.lazy = False
# 2022-01-16 12:05:24,484 - INFO - allennlp.common.params - validation_dataset_reader.cache_directory = None
# 2022-01-16 12:05:24,484 - INFO - allennlp.common.params - validation_dataset_reader.max_instances = None
# 2022-01-16 12:05:24,484 - INFO - allennlp.common.params - validation_dataset_reader.manual_distributed_sharding = False
# 2022-01-16 12:05:24,484 - INFO - allennlp.common.params - validation_dataset_reader.manual_multi_process_sharding = False
# 2022-01-16 12:05:24,484 - INFO - allennlp.common.params - validation_dataset_reader.token_indexers.tokens.type = pretrained_transformer_mismatched
# 2022-01-16 12:05:24,484 - INFO - allennlp.common.params - validation_dataset_reader.token_indexers.tokens.token_min_padding_length = 0
# 2022-01-16 12:05:24,484 - INFO - allennlp.common.params - validation_dataset_reader.token_indexers.tokens.model_name = roberta-large
# 2022-01-16 12:05:24,485 - INFO - allennlp.common.params - validation_dataset_reader.token_indexers.tokens.namespace = tags
# 2022-01-16 12:05:24,485 - INFO - allennlp.common.params - validation_dataset_reader.token_indexers.tokens.max_length = None
# 2022-01-16 12:05:24,736 - INFO - transformers.configuration_utils - loading configuration file https://s3.amazonaws.com/models.huggingface.co/bert/roberta-large-config.json from cache at /root/.cache/torch/transformers/c22e0b5bbb7c0cb93a87a2ae01263ae715b4c18d692b1740ce72cacaa99ad184.2d28da311092e99a05f9ee17520204614d60b0bfdb32f8a75644df7737b6a748
# 2022-01-16 12:05:24,737 - INFO - transformers.configuration_utils - Model config RobertaConfig {
#   "architectures": [
#     "RobertaForMaskedLM"
#   ],
#   "attention_probs_dropout_prob": 0.1,
#   "bos_token_id": 0,
#   "eos_token_id": 2,
#   "hidden_act": "gelu",
#   "hidden_dropout_prob": 0.1,
#   "hidden_size": 1024,
#   "initializer_range": 0.02,
#   "intermediate_size": 4096,
#   "layer_norm_eps": 1e-05,
#   "max_position_embeddings": 514,
#   "model_type": "roberta",
#   "num_attention_heads": 16,
#   "num_hidden_layers": 24,
#   "pad_token_id": 1,
#   "type_vocab_size": 1,
#   "vocab_size": 50265
# }
#
# 2022-01-16 12:05:25,032 - INFO - transformers.tokenization_utils - loading file https://s3.amazonaws.com/models.huggingface.co/bert/roberta-large-vocab.json from cache at /root/.cache/torch/transformers/1ae1f5b6e2b22b25ccc04c000bb79ca847aa226d0761536b011cf7e5868f0655.ef00af9e673c7160b4d41cfda1f48c5f4cba57d5142754525572a846a1ab1b9b
# 2022-01-16 12:05:25,032 - INFO - transformers.tokenization_utils - loading file https://s3.amazonaws.com/models.huggingface.co/bert/roberta-large-merges.txt from cache at /root/.cache/torch/transformers/f8f83199a6270d582d6245dc100e99c4155de81c9745c6248077018fe01abcfb.70bec105b4158ed9a1747fea67a43f5dee97855c64d62b6ec3742f4cfdb5feda
# 2022-01-16 12:05:25,301 - INFO - transformers.configuration_utils - loading configuration file https://s3.amazonaws.com/models.huggingface.co/bert/roberta-large-config.json from cache at /root/.cache/torch/transformers/c22e0b5bbb7c0cb93a87a2ae01263ae715b4c18d692b1740ce72cacaa99ad184.2d28da311092e99a05f9ee17520204614d60b0bfdb32f8a75644df7737b6a748
# 2022-01-16 12:05:25,302 - INFO - transformers.configuration_utils - Model config RobertaConfig {
#   "architectures": [
#     "RobertaForMaskedLM"
#   ],
#   "attention_probs_dropout_prob": 0.1,
#   "bos_token_id": 0,
#   "eos_token_id": 2,
#   "hidden_act": "gelu",
#   "hidden_dropout_prob": 0.1,
#   "hidden_size": 1024,
#   "initializer_range": 0.02,
#   "intermediate_size": 4096,
#   "layer_norm_eps": 1e-05,
#   "max_position_embeddings": 514,
#   "model_type": "roberta",
#   "num_attention_heads": 16,
#   "num_hidden_layers": 24,
#   "pad_token_id": 1,
#   "type_vocab_size": 1,
#   "vocab_size": 50265
# }
#
# 2022-01-16 12:05:25,599 - INFO - transformers.tokenization_utils - loading file https://s3.amazonaws.com/models.huggingface.co/bert/roberta-large-vocab.json from cache at /root/.cache/torch/transformers/1ae1f5b6e2b22b25ccc04c000bb79ca847aa226d0761536b011cf7e5868f0655.ef00af9e673c7160b4d41cfda1f48c5f4cba57d5142754525572a846a1ab1b9b
# 2022-01-16 12:05:25,599 - INFO - transformers.tokenization_utils - loading file https://s3.amazonaws.com/models.huggingface.co/bert/roberta-large-merges.txt from cache at /root/.cache/torch/transformers/f8f83199a6270d582d6245dc100e99c4155de81c9745c6248077018fe01abcfb.70bec105b4158ed9a1747fea67a43f5dee97855c64d62b6ec3742f4cfdb5feda
# 2022-01-16 12:05:25,731 - INFO - allennlp.common.params - validation_dataset_reader.use_subtrees = False
# 2022-01-16 12:05:25,731 - INFO - allennlp.common.params - validation_dataset_reader.granularity = 2-class
# input 0:  {"sentence": "Whether or not youre enlightened by any of Derridas lectures on the other and the self, Derrida is an undeniably fascinating and playful fellow."}
# prediction:  {"logits": [3.646597146987915, -2.953933000564575], "probs": [0.9986421465873718, 0.001357800792902708], "token_ids": [0, 5994, 50, 45, 47, 769, 38853, 30, 143, 9, 6113, 10505, 281, 25798, 15, 5, 97, 8, 5, 1403, 2156, 211, 14385, 4347, 16, 41, 35559, 12509, 8, 23317, 2598, 479, 2], "label": "1", "tokens": ["<s>", "\u0120Whether", "\u0120or", "\u0120not", "\u0120you", "\u0120re", "\u0120enlightened", "\u0120by", "\u0120any", "\u0120of", "\u0120Der", "rid", "as", "\u0120lectures", "\u0120on", "\u0120the", "\u0120other", "\u0120and", "\u0120the", "\u0120self", "\u0120,", "\u0120D", "err", "ida", "\u0120is", "\u0120an", "\u0120undeniably", "\u0120fascinating", "\u0120and", "\u0120playful", "\u0120fellow", "\u0120.", "</s>"]}
#
# 2022-01-16 12:05:28,687 - INFO - allennlp.models.archival - removing temporary unarchived model dir at /tmp/tmpfc_r79ne

# %% [markdown]
# # Sentiment Analysis with Hugging Face

# %%
# !pip install -q transformers

# %%
from transformers import pipeline

# %%
def classify(sequence,M):
   #DistilBertForSequenceClassification(default model)
    nlp_cls = pipeline('sentiment-analysis') 
    if M==1:
      print(nlp_cls.model.config)
    return nlp_cls(sequence)

# %%
seq=3
if seq==1:
  sequence="The battery on my Model9X phone doesn't last more than 6 hours and I'm unhappy about that."
if seq==2:
  sequence="The battery on my Model9X phone doesn't last more than 6 hours and I'm unhappy about that. I was really mad! I bought a Moel10x and things seem to be better. I'm super satisfied now."
if seq==3:
  sequence="The customer was very unhappy"
if seq==4:
  sequence="The customer was very satisfied"
print(sequence)
M=0 #display model cofiguration=1, default=0
CS=classify(sequence,M) 
print(CS)
# Out:
# The customer was very unhappy
# Downloading:   0%|          | 0.00/442 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/232k [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/629 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/230 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/268M [00:00<?, ?B/s]
# [{'label': 'NEGATIVE', 'score': 0.9997098445892334}]

# %% [markdown]
# #Sentiment Analysis with GPT-3

# %%
try:
  import openai
except:
  # !pip install openai
  import openai
# Out:
# Collecting openai
#   Downloading openai-0.11.5.tar.gz (466 kB)
#      |████████████████████████████████| 466 kB 5.3 MB/s
# Requirement already satisfied: requests>=2.20 in /usr/local/lib/python3.7/dist-packages (from openai) (2.23.0)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.7/dist-packages (from openai) (4.62.3)
# Collecting pandas>=1.2.3
#   Downloading pandas-1.3.5-cp37-cp37m-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (11.3 MB)
#      |████████████████████████████████| 11.3 MB 52.7 MB/s
# Collecting pandas-stubs>=1.1.0.11
#   Downloading pandas_stubs-1.2.0.40-py3-none-any.whl (161 kB)
#      |████████████████████████████████| 161 kB 53.1 MB/s
# Collecting openpyxl>=3.0.7
#   Downloading openpyxl-3.0.9-py2.py3-none-any.whl (242 kB)
#      |████████████████████████████████| 242 kB 63.1 MB/s
# Requirement already satisfied: et-xmlfile in /usr/local/lib/python3.7/dist-packages (from openpyxl>=3.0.7->openai) (1.1.0)
# Requirement already satisfied: python-dateutil>=2.7.3 in /usr/local/lib/python3.7/dist-packages (from pandas>=1.2.3->openai) (2.8.2)
# Requirement already satisfied: numpy>=1.17.3 in /usr/local/lib/python3.7/dist-packages (from pandas>=1.2.3->openai) (1.19.5)
# Requirement already satisfied: pytz>=2017.3 in /usr/local/lib/python3.7/dist-packages (from pandas>=1.2.3->openai) (2018.9)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.7/dist-packages (from pandas-stubs>=1.1.0.11->openai) (3.10.0.2)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.7/dist-packages (from python-dateutil>=2.7.3->pandas>=1.2.3->openai) (1.15.0)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.7/dist-packages (from requests>=2.20->openai) (3.0.4)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.7/dist-packages (from requests>=2.20->openai) (1.25.11)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.7/dist-packages (from requests>=2.20->openai) (2.10)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.7/dist-packages (from requests>=2.20->openai) (2021.10.8)
# Building wheels for collected packages: openai
#   Building wheel for openai (setup.py) ... done
#   Created wheel for openai: filename=openai-0.11.5-py3-none-any.whl size=161464 sha256=3ee0dc5e56e40f451e801fa04b2b3ab4b3aa247f80a8d486028b1cce6373fcbd
#   Stored in directory: /root/.cache/pip/wheels/5a/52/66/06c234d9748d81b9622d0b9765c3bd10e99d059ed93f13b0b3
# Successfully built openai
# Installing collected packages: pandas-stubs, pandas, openpyxl, openai
#   Attempting uninstall: pandas
#     Found existing installation: pandas 1.1.5
#     Uninstalling pandas-1.1.5:
#       Successfully uninstalled pandas-1.1.5
#   Attempting uninstall: openpyxl
#     Found existing installation: openpyxl 2.5.9
#     Uninstalling openpyxl-2.5.9:
#       Successfully uninstalled openpyxl-2.5.9
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# google-colab 1.0.0 requires pandas~=1.1.0; python_version >= "3.0", but you have pandas 1.3.5 which is incompatible.
# Successfully installed openai-0.11.5 openpyxl-3.0.9 pandas-1.3.5 pandas-stubs-1.2.0.40

# %%
import os
import openai
os.environ['OPENAI_API_KEY'] ='[YOUR KEY]'
print(os.getenv('OPENAI_API_KEY'))
openai.api_key = os.getenv("OPENAI_API_KEY")
# Out:
# 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

# %%
response = openai.Completion.create(
  engine="davinci",
  prompt="This is a Sentence sentiment classifier\nSentence: \"The customer was satisfied\"\nSentiment: Positive\n###\nSentence: \"The customer was not satisfied\"\nSentiment: Negative\n###\nSentence: \"The service was 👍\"\nSentiment: Positive\n###\nSentence: \"This is the link to the review\"\nSentiment: Neutral\n###\nSentence text\n\n\n1. \"I loved the new Batman movie!\"\n2. \"I hate it when my phone battery dies\"\n3. \"My day has been 👍\"\n4. \"This is the link to the article\"\n5. \"This new music video blew my mind\"\n\n\nSentence sentiment ratings:\n1: Positive\n2: Negative\n3: Positive\n4: Neutral\n5: Positive\n\n\n###\nSentence text\n\n\n1. \"I can't stand this product\"\n2. \"The service was bad! 😠\"\n3. \"Though the customer seemed unhappy she was in fact satisfied but thinking of something else at the time, which gave a false impression\"\n4. \"The support team was ❤️❤️\"\n5. \"Here is the link to the product.\"\n\n\nSentence sentiment ratings:\n",
  temperature=0.3,
  max_tokens=60,
  top_p=1,
  frequency_penalty=0,
  presence_penalty=0,
  stop=["###"]
)
r = (response["choices"][0])
print(r["text"])
# Out:
# 1: Negative
# 2: Negative
# 3: Positive
# 4: Positive
# 5: Neutral
